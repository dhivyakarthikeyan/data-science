# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("MySession").getOrCreate()
# Your code here
spark.stop()

# %%
spark = SparkSession.builder.appName("RDD Demo").getOrCreate()
sc = spark.sparkContext
data = [1,2,3,4,5,6]
rdd = sc.parallelize(data)
mapped_rdd = rdd.map(lambda x:x*2)
filtered_rdd = mapped_rdd.filter(lambda x:x%2==0)
result = filtered_rdd.collect()
print("Final Result:", result)
print("Count of elements", rdd.count())
print("Sum of elements", rdd.reduce(lambda x,y:x+y))
print("First element:", rdd.first())
# Out:
# Final Result: [2, 4, 6, 8, 10, 12]
# Count of elements 6
# Sum of elements 21
# First element: 1

# %%
import os
from pyspark.sql import SparkSession

#python_path = r'C:\Users\Dhivya Karthikeyan\AppData\Local\Microsoft\WindowsApps\python.exe'
#os.environ['PYSPARK_PYTHON'] = python_path
#os.environ['PYSPARK_DRIVER_PYTHON'] = python_path


# Initialize Spark session
spark = SparkSession.builder \
    .appName("Simple PySpark Test") \
    .getOrCreate()
    #.config("spark.python.worker.exec", python_path) \


#spark.conf.set("spark.sql.execution.pyspark.udf.faulthandler.enabled", "true")

# Sample data
data = [("Alice", 29), ("Bob", 35), ("Charlie", 30), ("David", 25)]

# Create DataFrame
df = spark.createDataFrame(data, ["Name", "Age"])

# Show the DataFrame
df.show()

# Perform a simple transformation: Filter by age greater than 30
filtered_df = df.filter(df.Age > 30)

# Show the filtered DataFrame
filtered_df.show()

# Stop Spark session
spark.stop()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |  Alice| 29|
# |    Bob| 35|
# |Charlie| 30|
# |  David| 25|
# +-------+---+
#
# +----+---+
# |Name|Age|
# +----+---+
# | Bob| 35|
# +----+---+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pyspark.sql import SparkSession

# Create SparkSession
spark = SparkSession.builder \
    .appName("Iris Data Comparison") \
    .getOrCreate()

# %%
#/Iris.csv
import pandas as pd

iris_csv_pd = pd.read_csv("/Iris.csv")
iris_json_pd = pd.read_json("/Iris.json", lines=True)
iris_parquet_pd = pd.read_parquet("/Iris.parquet")

print("iris_csv sample: ")
iris_csv_pd.head()
# Out:
# iris_csv sample:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris_csv_spark = spark.read.csv("/Iris.csv", header=True, inferSchema=True)
iris_json_spark = spark.read.json("/Iris.json")
iris_parquet_spark = spark.read.parquet("/Iris.parquet")

print("iris_csv sample: ")
iris_csv_spark.show()
# Out:
# iris_csv sample:
# +------------+-----------+------------+-----------+-------+
# |sepal.length|sepal.width|petal.length|petal.width|variety|
# +------------+-----------+------------+-----------+-------+
# |         5.1|        3.5|         1.4|        0.2| Setosa|
# |         4.9|        3.0|         1.4|        0.2| Setosa|
# |         4.7|        3.2|         1.3|        0.2| Setosa|
# |         4.6|        3.1|         1.5|        0.2| Setosa|
# |         5.0|        3.6|         1.4|        0.2| Setosa|
# |         5.4|        3.9|         1.7|        0.4| Setosa|
# |         4.6|        3.4|         1.4|        0.3| Setosa|
# |         5.0|        3.4|         1.5|        0.2| Setosa|
# |         4.4|        2.9|         1.4|        0.2| Setosa|
# |         4.9|        3.1|         1.5|        0.1| Setosa|
# |         5.4|        3.7|         1.5|        0.2| Setosa|
# |         4.8|        3.4|         1.6|        0.2| Setosa|
# |         4.8|        3.0|         1.4|        0.1| Setosa|
# |         4.3|        3.0|         1.1|        0.1| Setosa|
# |         5.8|        4.0|         1.2|        0.2| Setosa|
# |         5.7|        4.4|         1.5|        0.4| Setosa|
# |         5.4|        3.9|         1.3|        0.4| Setosa|
# |         5.1|        3.5|         1.4|        0.3| Setosa|
# |         5.7|        3.8|         1.7|        0.3| Setosa|
# |         5.1|        3.8|         1.5|        0.3| Setosa|
# +------------+-----------+------------+-----------+-------+
# only showing top 20 rows

# %%
iris_csv_spark.printSchema()
#
# Out:
# root
#  |-- sepal.length: double (nullable = true)
#  |-- sepal.width: double (nullable = true)
#  |-- petal.length: double (nullable = true)
#  |-- petal.width: double (nullable = true)
#  |-- variety: string (nullable = true)

# %%
for col_name in iris_csv_spark.columns:
  print(col_name)
# Out:
# sepal.length
# sepal.width
# petal.length
# petal.width
# variety

# %%
iris_csv_spark = iris_csv_spark.withColumnRenamed("Sepal.width", "Sepal_width")
iris_csv_spark = iris_csv_spark.withColumnRenamed("Petal.width", "Petal_width")
iris_csv_spark.columns
# Out:
# ['sepal.length', 'Sepal_width', 'petal.length', 'Petal_width', 'variety']

# %%
from pyspark.sql.functions import col, avg

avg_sw_spark = iris_csv_spark.select(avg(col("sepal_width"))).collect()
avg_sw_spark[0][0]
# Out:
# 3.057333333333334

# %%
filtered_spark = iris_csv_spark.filter(col("sepal_width") > avg_sw_spark[0][0])
filtered_spark.show(5)
# Out:
# +------------+-----------+------------+-----------+-------+
# |sepal.length|Sepal_width|petal.length|Petal_width|variety|
# +------------+-----------+------------+-----------+-------+
# |         5.1|        3.5|         1.4|        0.2| Setosa|
# |         4.7|        3.2|         1.3|        0.2| Setosa|
# |         4.6|        3.1|         1.5|        0.2| Setosa|
# |         5.0|        3.6|         1.4|        0.2| Setosa|
# |         5.4|        3.9|         1.7|        0.4| Setosa|
# +------------+-----------+------------+-----------+-------+
# only showing top 5 rows

# %%
iris_csv_spark = iris_csv_spark.withColumnRenamed("sepal.length", "sepal_length")
iris_csv_spark = iris_csv_spark.withColumnRenamed("petal.length", "petal_length")
iris_csv_spark = iris_csv_spark.withColumnRenamed("petal.width", "petal_width")
iris_csv_spark.show(5)
# Out:
# +------------+-----------+------------+-----------+-------+
# |sepal_length|Sepal_width|petal_length|Petal_width|variety|
# +------------+-----------+------------+-----------+-------+
# |         5.1|        3.5|         1.4|        0.2| Setosa|
# |         4.9|        3.0|         1.4|        0.2| Setosa|
# |         4.7|        3.2|         1.3|        0.2| Setosa|
# |         4.6|        3.1|         1.5|        0.2| Setosa|
# |         5.0|        3.6|         1.4|        0.2| Setosa|
# +------------+-----------+------------+-----------+-------+
# only showing top 5 rows

# %%
df = iris_csv_spark
df.show(5)
df.createOrReplaceTempView("Iris")
# Out:
# +------------+-----------+------------+-----------+-------+
# |sepal_length|Sepal_width|petal_length|Petal_width|variety|
# +------------+-----------+------------+-----------+-------+
# |         5.1|        3.5|         1.4|        0.2| Setosa|
# |         4.9|        3.0|         1.4|        0.2| Setosa|
# |         4.7|        3.2|         1.3|        0.2| Setosa|
# |         4.6|        3.1|         1.5|        0.2| Setosa|
# |         5.0|        3.6|         1.4|        0.2| Setosa|
# +------------+-----------+------------+-----------+-------+
# only showing top 5 rows

# %%
filtered = spark.sql("""
SELECT * FROM iris
WHERE petal_length > 1.50
""")
filtered.show(5)
# Out:
# +------------+-----------+------------+-----------+-------+
# |sepal_length|Sepal_width|petal_length|Petal_width|variety|
# +------------+-----------+------------+-----------+-------+
# |         5.4|        3.9|         1.7|        0.4| Setosa|
# |         4.8|        3.4|         1.6|        0.2| Setosa|
# |         5.7|        3.8|         1.7|        0.3| Setosa|
# |         5.4|        3.4|         1.7|        0.2| Setosa|
# |         5.1|        3.3|         1.7|        0.5| Setosa|
# +------------+-----------+------------+-----------+-------+
# only showing top 5 rows

# %%
avg_sepal_width = spark.sql("""
select variety, ROUND(avg(sepal_width), 2) as avg_sepal_width
from iris
group by variety
order by variety
""")
avg_sepal_width.show()
# Out:
# +----------+---------------+
# |   variety|avg_sepal_width|
# +----------+---------------+
# |    Setosa|           3.43|
# |Versicolor|           2.77|
# | Virginica|           2.97|
# +----------+---------------+

# %%
def classify_by_petal_length(petal_length):
  if petal_length < 2.0:
    return "Small"
  elif petal_length < 5.0:
    return "Medium"
  else:
    return "Large"

# %%
def classify_by_sepal_width(sepal_width):
  if sepal_width < 3.0:
    return "Narrow"
  elif sepal_width < 3.5:
    return "Moderate"
  else:
    return "Wide"

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

petal_size_udf = udf(classify_by_petal_length, StringType())
sepal_size_udf = udf(classify_by_sepal_width, StringType())

# %%
iris_classified = iris_csv_spark.withColumn("petal_size", petal_size_udf("petal_length"))\
.withColumn("sepal_size", sepal_size_udf("sepal_width"))
iris_classified.show(10)
# Out:
# +------------+-----------+------------+-----------+-------+----------+----------+
# |sepal_length|Sepal_width|petal_length|Petal_width|variety|petal_size|sepal_size|
# +------------+-----------+------------+-----------+-------+----------+----------+
# |         5.1|        3.5|         1.4|        0.2| Setosa|     Small|      Wide|
# |         4.9|        3.0|         1.4|        0.2| Setosa|     Small|  Moderate|
# |         4.7|        3.2|         1.3|        0.2| Setosa|     Small|  Moderate|
# |         4.6|        3.1|         1.5|        0.2| Setosa|     Small|  Moderate|
# |         5.0|        3.6|         1.4|        0.2| Setosa|     Small|      Wide|
# |         5.4|        3.9|         1.7|        0.4| Setosa|     Small|      Wide|
# |         4.6|        3.4|         1.4|        0.3| Setosa|     Small|  Moderate|
# |         5.0|        3.4|         1.5|        0.2| Setosa|     Small|  Moderate|
# |         4.4|        2.9|         1.4|        0.2| Setosa|     Small|    Narrow|
# |         4.9|        3.1|         1.5|        0.1| Setosa|     Small|  Moderate|
# +------------+-----------+------------+-----------+-------+----------+----------+
# only showing top 10 rows

# %%
from pyspark.sql import SparkSession

# Create SparkSession
spark = SparkSession.builder \
    .appName("Global Student Migration") \
    .getOrCreate()

edu = spark.read.csv("/content/global_student_migration.csv", header=True, inferSchema=True)
edu.show(5)
# Out:
# +----------+--------------+-------------------+----------------+--------------------+--------------------+---------------+------------------+--------------------+-------------------+---------------+----------------+-----------------+-----------------+-------------------+------------+--------------------+--------------------+-------------------------+----------+
# |student_id|origin_country|destination_country|destination_city|     university_name|         course_name| field_of_study|year_of_enrollment|scholarship_received|  enrollment_reason|graduation_year|placement_status|placement_country|placement_company|starting_salary_usd|gpa_or_score|         visa_status|post_graduation_visa|language_proficiency_test|test_score|
# +----------+--------------+-------------------+----------------+--------------------+--------------------+---------------+------------------+--------------------+-------------------+---------------+----------------+-----------------+-----------------+-------------------+------------+--------------------+--------------------+-------------------------+----------+
# |    S00001|       Finland|             Russia|          Moscow|Lomonosov Moscow ...|    Computer Science|    Engineering|              2021|                  No|     Higher Ranking|           2024|          Placed|           Russia|        Microsoft|              36416|        3.92|              Tier 4|         Work Permit|                    TOEFL|       7.8|
# |    S00002|            UK|            Germany|          Aachen|         RWTH Aachen|   Civil Engineering|            Law|              2023|                 Yes|  Job Opportunities|           2024|          Placed|          Germany|           Google|              32956|         2.6|        Study Permit|                 OPT|                      PTE|       7.9|
# |    S00003|       Ireland|             Canada|       Vancouver|University of Bri...|                 Law|           Arts|              2019|                  No|        Scholarship|           2020|      Not Placed|              N/A|              N/A|                  0|        2.72|                  F1|           Blue Card|                     None|       0.0|
# |    S00004|           UAE|                 UK|      Birmingham|University of Bir...|        Data Science|Social Sciences|              2021|                 Yes|    Quality of Life|           2023|          Placed|               UK|            Apple|              50892|        3.71|Schengen Student ...|                 PSW|                     None|       0.0|
# |    S00005|  South Africa|            Germany|       Stuttgart|University of Stu...|Business Administ...|            Law|              2020|                 Yes|Political Stability|           2021|          Placed|          Germany|              IBM|              54790|        2.96|Schengen Student ...|                 OPT|                      PTE|       8.2|
# +----------+--------------+-------------------+----------------+--------------------+--------------------+---------------+------------------+--------------------+-------------------+---------------+----------------+-----------------+-----------------+-------------------+------------+--------------------+--------------------+-------------------------+----------+
# only showing top 5 rows

# %%
edu.columns
# Out:
# ['student_id',
#  'origin_country',
#  'destination_country',
#  'destination_city',
#  'university_name',
#  'course_name',
#  'field_of_study',
#  'year_of_enrollment',
#  'scholarship_received',
#  'enrollment_reason',
#  'graduation_year',
#  'placement_status',
#  'placement_country',
#  'placement_company',
#  'starting_salary_usd',
#  'gpa_or_score',
#  'visa_status',
#  'post_graduation_visa',
#  'language_proficiency_test',
#  'test_score']

# %%
edu.scholarship_received
# Out:
# Column<'scholarship_received'>

# %%
scholarship = edu.filter(edu["scholarship_received"] == 'Yes')
scholarship.show(5)
scholarship.count()
# Out:
# +----------+--------------+-------------------+----------------+--------------------+--------------------+---------------+------------------+--------------------+-------------------+---------------+----------------+-----------------+-----------------+-------------------+------------+--------------------+--------------------+-------------------------+----------+
# |student_id|origin_country|destination_country|destination_city|     university_name|         course_name| field_of_study|year_of_enrollment|scholarship_received|  enrollment_reason|graduation_year|placement_status|placement_country|placement_company|starting_salary_usd|gpa_or_score|         visa_status|post_graduation_visa|language_proficiency_test|test_score|
# +----------+--------------+-------------------+----------------+--------------------+--------------------+---------------+------------------+--------------------+-------------------+---------------+----------------+-----------------+-----------------+-------------------+------------+--------------------+--------------------+-------------------------+----------+
# |    S00002|            UK|            Germany|          Aachen|         RWTH Aachen|   Civil Engineering|            Law|              2023|                 Yes|  Job Opportunities|           2024|          Placed|          Germany|           Google|              32956|         2.6|        Study Permit|                 OPT|                      PTE|       7.9|
# |    S00004|           UAE|                 UK|      Birmingham|University of Bir...|        Data Science|Social Sciences|              2021|                 Yes|    Quality of Life|           2023|          Placed|               UK|            Apple|              50892|        3.71|Schengen Student ...|                 PSW|                     None|       0.0|
# |    S00005|  South Africa|            Germany|       Stuttgart|University of Stu...|Business Administ...|            Law|              2020|                 Yes|Political Stability|           2021|          Placed|          Germany|              IBM|              54790|        2.96|Schengen Student ...|                 OPT|                      PTE|       8.2|
# |    S00006|           UAE|       South Africa|        Pretoria|University of Pre...|Mechanical Engine...|    Engineering|              2022|                 Yes|  Job Opportunities|           2023|      Not Placed|              N/A|              N/A|                  0|        2.69|                  J1|           Blue Card|                    TOEFL|       7.4|
# |    S00007|           UAE|                 UK|       Edinburgh|University of Edi...|        Architecture|            Law|              2019|                 Yes|    Quality of Life|           2021|      Not Placed|              N/A|              N/A|                  0|        2.99|        Study Permit|           Blue Card|                 Duolingo|       5.6|
# +----------+--------------+-------------------+----------------+--------------------+--------------------+---------------+------------------+--------------------+-------------------+---------------+----------------+-----------------+-----------------+-------------------+------------+--------------------+--------------------+-------------------------+----------+
# only showing top 5 rows
# 2577

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

def get_scholarship_received(scholarship_received):
  if scholarship_received == 'Yes':
    return True
  else:
    return False

#scholarship_udf = udf(get_scholarship_received, StringType())

def get_count(edu):
  scholarship = edu.filter(edu["scholarship_received"] == 'Yes')
  return scholarship.count()

# %%
country_usa = edu.filter(edu["destination_country"] == 'USA')
country_usa.show(5)
# Out:
# +----------+--------------+-------------------+----------------+-------------------+-----------+----------------+------------------+--------------------+-------------------+---------------+----------------+-----------------+-----------------+-------------------+------------+------------+--------------------+-------------------------+----------+
# |student_id|origin_country|destination_country|destination_city|    university_name|course_name|  field_of_study|year_of_enrollment|scholarship_received|  enrollment_reason|graduation_year|placement_status|placement_country|placement_company|starting_salary_usd|gpa_or_score| visa_status|post_graduation_visa|language_proficiency_test|test_score|
# +----------+--------------+-------------------+----------------+-------------------+-----------+----------------+------------------+--------------------+-------------------+---------------+----------------+-----------------+-----------------+-------------------+------------+------------+--------------------+-------------------------+----------+
# |    S00014|            UK|                USA|          Boston| Harvard University| Psychology|     Engineering|              2021|                 Yes|  Job Opportunities|           2024|      Not Placed|              N/A|              N/A|                  0|        2.91|Study Permit|                 OPT|                    TOEFL|       6.5|
# |    S00016|  South Africa|                USA|   San Francisco|        UC Berkeley|    Finance| Social Sciences|              2022|                  No|Political Stability|           2023|          Placed|              USA|          Siemens|              87234|         3.0|          F1|           Blue Card|                    IELTS|       6.0|
# |    S00033|  South Africa|                USA|     Los Angeles|               UCLA|    Finance|Natural Sciences|              2021|                  No|  Job Opportunities|           2023|          Placed|              USA|          Siemens|             131755|         2.8|          F1|         Work Permit|                      PTE|       8.3|
# |    S00046|  South Africa|                USA|   San Francisco|Stanford University|    Finance|            Arts|              2019|                 Yes|  Job Opportunities|           2021|      Not Placed|              N/A|              N/A|                  0|        3.08|Study Permit|                 OPT|                     None|       0.0|
# |    S00047|       Ireland|                USA|        New York|                NYU|     Design|            Arts|              2021|                 Yes|        Scholarship|           2022|      Not Placed|              N/A|              N/A|                  0|        3.37|Study Permit|           Blue Card|                     None|       0.0|
# +----------+--------------+-------------------+----------------+-------------------+-----------+----------------+------------------+--------------------+-------------------+---------------+----------------+-----------------+-----------------+-------------------+------------+------------+--------------------+-------------------------+----------+
# only showing top 5 rows

# %%
edu.createOrReplaceTempView("edu")
avg_gpa = spark.sql("""
    SELECT ROUND(AVG(gpa_or_score), 2) AS avg_gpa
    FROM edu
    where placement_status = 'Placed' and destination_country = 'USA'
""")
avg_gpa.show()
# Out:
# +-------+
# |avg_gpa|
# +-------+
# |   3.26|
# +-------+

# %%
top5 = spark.sql("""
    SELECT destination_country , count(*) as count
    FROM edu
    group by year_of_enrollment
    order by count desc
    limit 5
""")
top5.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipython-input-1388903570.py in <cell line: 0>()
# ----> 1 top5 = spark.sql("""
#       2     SELECT destination_country , count(*) as count
#       3     FROM edu
#       4     group by year_of_enrollment
#       5     order by count desc
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in sql(self, sqlQuery, args, **kwargs)
#    1808                     messageParameters={"arg_name": "args", "arg_type": type(args).__name__},
#    1809                 )
# -> 1810             return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1811         finally:
#    1812             if len(kwargs) > 0:
#
# /usr/local/lib/python3.12/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1360
#    1361         answer = self.gateway_client.send_command(command)
# -> 1362         return_value = get_return_value(
#    1363             answer, self.gateway_client, self.target_id, self.name)
#    1364
#
# /usr/local/lib/python3.12/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     286                 # Hide where the exception came from that shows a non-Pythonic
#     287                 # JVM exception message.
# --> 288                 raise converted from None
#     289             else:
#     290                 raise
#
# AnalysisException: [MISSING_AGGREGATION] The non-aggregating expression "destination_country" is based on columns which are not participating in the GROUP BY clause.
# Add the columns or the expression to the GROUP BY, aggregate the expression, or use "any_value(destination_country)" if you do not care which of the values within a group is returned. SQLSTATE: 42803;
# GlobalLimit 5
# +- LocalLimit 5
#    +- Sort [count#471L DESC NULLS LAST], true
#       +- Aggregate [year_of_enrollment#24], [destination_country#19, count(1) AS count#471L]
#          +- SubqueryAlias edu
#             +- View (`edu`, [student_id#17, origin_country#18, destination_country#19, destination_city#20, university_name#21, course_name#22, field_of_study#23, year_of_enrollment#24, scholarship_received#25, enrollment_reason#26, graduation_year#27, placement_status#28, placement_country#29, placement_company#30, starting_salary_usd#31, gpa_or_score#32, visa_status#33, post_graduation_visa#34, language_proficiency_test#35, test_score#36])
#                +- Relation [student_id#17,origin_country#18,destination_country#19,destination_city#20,university_name#21,course_name#22,field_of_study#23,year_of_enrollment#24,scholarship_received#25,enrollment_reason#26,graduation_year#27,placement_status#28,placement_country#29,placement_company#30,starting_salary_usd#31,gpa_or_score#32,visa_status#33,post_graduation_visa#34,language_proficiency_test#35,test_score#36] csv

# %%
from pyspark.sql import functions as F
def top5(edu, year):
  result = (
    edu.filter(F.col("year_of_enrollment") == year)\
    .groupBy("destination_country")\
    .agg(F.count("*").alias("count"))\
    .orderBy(F.desc("count"))\
    .limit(5)
  )
  return result

top5 = top5(edu, 2019)
top5.show()
# Out:
# +-------------------+-----+
# |destination_country|count|
# +-------------------+-----+
# |                UAE|  117|
# |       South Africa|  108|
# |             Russia|  107|
# |            Germany|  106|
# |              India|  101|
# +-------------------+-----+

# %%
edu.columns
# Out:
# ['student_id',
#  'origin_country',
#  'destination_country',
#  'destination_city',
#  'university_name',
#  'course_name',
#  'field_of_study',
#  'year_of_enrollment',
#  'scholarship_received',
#  'enrollment_reason',
#  'graduation_year',
#  'placement_status',
#  'placement_country',
#  'placement_company',
#  'starting_salary_usd',
#  'gpa_or_score',
#  'visa_status',
#  'post_graduation_visa',
#  'language_proficiency_test',
#  'test_score']

# %%
filtered_df = (
      edu.filter(
          (F.col("university_name").rlike("Technology|Engineering")) &
          (F.col("placement_status") == 'Placed')
      )
  )
result = filtered_df.agg(F.avg("starting_salary_usd").alias("avg_salary")).collect()[0]["avg_salary"]
result
# Out:
# 93310.02564102564

# %%
def avg_salary(df):
  filtered_df = (
      df.filter(
          (F.col("university_name").rlike("Technology|Engineering")) &
          (F.col("placement_status") == 'Placed')
      )
  )
  result = filtered_df.agg(F.avg("starting_salary_usd").alias("avg_salary")).collect()[0]["avg_salary"]

  return result

# %%
avg_salary = avg_salary(edu)
print("Average starting salary:", avg_salary)
# Out:
# Average starting salary: 93310.02564102564

# %%
from pyspark.sql import functions as F

def avg_salary_by_university(df):
    """
    Calculates the average starting salary for students who studied at universities
    with 'Technology' or 'Engineering' in their name and got placed,
    grouped by university.

    Parameters:
    df : pyspark.sql.DataFrame
         Must contain columns 'university_name', 'placed', and 'starting_salary'

    Returns:
    pyspark.sql.DataFrame
         DataFrame with university_name and average starting salary
    """

    result = (
        df.filter(
            (F.col("university_name").rlike("(?i)Technology|Engineering")) &
            (F.col("placement_status") == 'Placed')   # or == "Yes" depending on schema
        )
        .groupBy("university_name")
        .agg(F.avg("starting_salary_usd").alias("avg_salary"))
        .orderBy(F.desc("avg_salary"))
    )

    return result

# %%
avg_salaries = avg_salary_by_university(edu)
avg_salaries.show()
# Out:
# +--------------------+-----------------+
# |     university_name|       avg_salary|
# +--------------------+-----------------+
# |Moscow Institute ...|93310.02564102564|
# +--------------------+-----------------+

# %%
edu.filter(F.col("university_name").rlike("(?i)Technology|Engineering")).show()
# Out:
# +----------+--------------+-------------------+----------------+--------------------+--------------------+----------------+------------------+--------------------+-----------------+---------------+----------------+-----------------+-----------------+-------------------+------------+--------------------+--------------------+-------------------------+----------+
# |student_id|origin_country|destination_country|destination_city|     university_name|         course_name|  field_of_study|year_of_enrollment|scholarship_received|enrollment_reason|graduation_year|placement_status|placement_country|placement_company|starting_salary_usd|gpa_or_score|         visa_status|post_graduation_visa|language_proficiency_test|test_score|
# +----------+--------------+-------------------+----------------+--------------------+--------------------+----------------+------------------+--------------------+-----------------+---------------+----------------+-----------------+-----------------+-------------------+------------+--------------------+--------------------+-------------------------+----------+
# |    S00019|  South Africa|             Russia|          Moscow|Moscow Institute ...|Electrical Engine...|            Arts|              2019|                  No|  Quality of Life|           2021|      Not Placed|              N/A|              N/A|                  0|        3.83|        Study Permit|                 PSW|                    IELTS|       5.2|
# |    S00025|           UAE|             Russia|          Moscow|Moscow Institute ...|       Biotechnology|             Law|              2020|                  No|   Higher Ranking|           2022|          Placed|           Russia|         Deloitte|              78449|        2.67|        Study Permit|     Post-Study Visa|                 Duolingo|       7.9|
# |    S00092|       Germany|             Russia|          Moscow|Moscow Institute ...|          Psychology|        Medicine|              2022|                  No|   Higher Ranking|           2023|          Placed|           Russia|            Tesla|             134172|        3.22|        Student Visa|         Work Permit|                    IELTS|       7.2|
# |    S00122|       Ireland|             Russia|          Moscow|Moscow Institute ...|Business Administ...|        Medicine|              2021|                 Yes|  Quality of Life|           2022|          Placed|           Russia|           Google|              72279|        3.24|              Tier 4|                 PSW|                     None|       0.0|
# |    S00191|        Canada|             Russia|          Moscow|Moscow Institute ...|              Design| Social Sciences|              2019|                 Yes|   Higher Ranking|           2022|          Placed|           Russia|              IBM|             111110|        3.56|Schengen Student ...|           Blue Card|                    IELTS|       6.1|
# |    S00236|       Ireland|             Russia|          Moscow|Moscow Institute ...|              Design|            Arts|              2021|                  No|  Quality of Life|           2024|      Not Placed|              N/A|              N/A|                  0|        3.99|                  J1|         Work Permit|                 Duolingo|       7.4|
# |    S00304|           USA|             Russia|          Moscow|Moscow Institute ...|Electrical Engine...|        Medicine|              2022|                 Yes|      Scholarship|           2024|      Not Placed|              N/A|              N/A|                  0|        3.97|                  J1|         Work Permit|                    IELTS|       8.9|
# |    S00312|         India|             Russia|          Moscow|Moscow Institute ...|   Civil Engineering|     Engineering|              2019|                 Yes|Job Opportunities|           2020|      Not Placed|              N/A|              N/A|                  0|        3.33|        Study Permit|     Post-Study Visa|                    IELTS|       7.5|
# |    S00342|         India|             Russia|          Moscow|Moscow Institute ...|Business Administ...|Natural Sciences|              2021|                 Yes|Job Opportunities|           2023|          Placed|           Russia|         McKinsey|             129891|        3.08|        Study Permit|         Work Permit|                    TOEFL|       7.0|
# |    S00550|            UK|             Russia|          Moscow|Moscow Institute ...|Electrical Engine...|        Business|              2022|                 Yes|  Quality of Life|           2023|      Not Placed|              N/A|              N/A|                  0|        3.17|        Study Permit|                 PSW|                     None|       0.0|
# |    S00582|        Canada|             Russia|          Moscow|Moscow Institute ...|       Biotechnology|     Engineering|              2022|                 Yes|  Quality of Life|           2024|      Not Placed|              N/A|              N/A|                  0|        3.32|                  J1|         Work Permit|                     None|       0.0|
# |    S00628|       Germany|             Russia|          Moscow|Moscow Institute ...|             Finance| Social Sciences|              2019|                  No|  Quality of Life|           2021|      Not Placed|              N/A|              N/A|                  0|        3.81|        Study Permit|         Work Permit|                     None|       0.0|
# |    S00651|  South Africa|             Russia|          Moscow|Moscow Institute ...|           Economics| Social Sciences|              2023|                 Yes|   Higher Ranking|           2025|          Placed|           Russia|        Microsoft|             126677|        3.81|              Tier 4|           Blue Card|                     None|       0.0|
# |    S00684|       Germany|             Russia|          Moscow|Moscow Institute ...|             Finance|        Business|              2022|                  No|   Higher Ranking|           2025|          Placed|           Russia|          Siemens|             113988|         3.7|              Tier 4|         Work Permit|                 Duolingo|       8.6|
# |    S00789|       Germany|             Russia|          Moscow|Moscow Institute ...|              Design|Natural Sciences|              2021|                  No|   Higher Ranking|           2024|      Not Placed|              N/A|              N/A|                  0|        2.51|              Tier 4|     Post-Study Visa|                      PTE|       7.2|
# |    S00795|         India|             Russia|          Moscow|Moscow Institute ...|                 Law|        Business|              2021|                 Yes|Job Opportunities|           2023|      Not Placed|              N/A|              N/A|                  0|        2.81|                  J1|         Work Permit|                     None|       0.0|
# |    S00813|       Ireland|             Russia|          Moscow|Moscow Institute ...|   Political Science|        Medicine|              2023|                  No|Job Opportunities|           2024|      Not Placed|              N/A|              N/A|                  0|        3.42|Schengen Student ...|                 OPT|                    TOEFL|       6.5|
# |    S00880|       Germany|             Russia|          Moscow|Moscow Institute ...|           Economics| Social Sciences|              2019|                 Yes|   Higher Ranking|           2020|      Not Placed|              N/A|              N/A|                  0|        2.96|                  F1|     Post-Study Visa|                      PTE|       8.9|
# |    S00890|  South Africa|             Russia|          Moscow|Moscow Institute ...|          Psychology|Computer Science|              2021|                  No|Job Opportunities|           2023|      Not Placed|              N/A|              N/A|                  0|         3.5|        Study Permit|                 OPT|                    IELTS|       8.7|
# |    S00893|         India|             Russia|          Moscow|Moscow Institute ...|    Computer Science|     Engineering|              2023|                  No|   Higher Ranking|           2024|          Placed|           Russia|           Google|              96781|        3.46|              Tier 4|         Work Permit|                    TOEFL|       5.6|
# +----------+--------------+-------------------+----------------+--------------------+--------------------+----------------+------------------+--------------------+-----------------+---------------+----------------+-----------------+-----------------+-------------------+------------+--------------------+--------------------+-------------------------+----------+
# only showing top 20 rows

# %%
edu.columns
# Out:
# ['student_id',
#  'origin_country',
#  'destination_country',
#  'destination_city',
#  'university_name',
#  'course_name',
#  'field_of_study',
#  'year_of_enrollment',
#  'scholarship_received',
#  'enrollment_reason',
#  'graduation_year',
#  'placement_status',
#  'placement_country',
#  'placement_company',
#  'starting_salary_usd',
#  'gpa_or_score',
#  'visa_status',
#  'post_graduation_visa',
#  'language_proficiency_test',
#  'test_score']

# %%
from pyspark.sql import functions as F

def avg_toefl_by_origin(df):
    """
    Returns the average TOEFL score by origin country for students
    who were placed in a different country and took the TOEFL test.

    Parameters:
    df : pyspark.sql.DataFrame
         Must contain columns 'origin_country', 'placement_country',
         'toefl_score', and 'placed'

    Returns:
    pyspark.sql.DataFrame
         DataFrame with origin_country and average TOEFL score
    """

    result = (
        df.filter(
            (F.col("placement_status") == 'Placed') &                # or == "Yes" depending on schema
            (F.col("test_score").isNotNull()) &       # must have taken TOEFL
            (F.col("origin_country") != F.col("destination_country"))  # placed abroad
        )
        .groupBy("origin_country")
        .agg(F.avg("test_score").alias("avg_toefl_score"))
        .orderBy(F.desc("avg_toefl_score"))
    )

    return result

# %%
avg_scores = avg_toefl_by_origin(edu)
avg_scores.show()
# Out:
# +--------------+------------------+
# |origin_country|   avg_toefl_score|
# +--------------+------------------+
# |        Canada| 6.175280898876403|
# |         India| 5.933877551020407|
# |       Germany| 5.781021897810218|
# |           USA| 5.767088607594938|
# |            UK| 5.613580246913581|
# |        Russia| 5.529770992366416|
# |       Finland|5.4856540084388214|
# |       Ireland| 5.418283582089553|
# |  South Africa| 5.403174603174605|
# |           UAE| 5.267410714285712|
# +--------------+------------------+
